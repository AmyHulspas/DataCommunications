# %%
import librosa
import librosa.display
import matplotlib.pylab as plt
import numpy
# D:\School\EE Year 2\Python\Dashboard\DataCommunications\dashboard\
# D:/School/EE Year 2/Python/Dashboard/DataCommunications/dashboard/
#y, sr = librosa.load('D:\School\EE Year 2\Python\Dashboard\DataCommunications\dashboard\lectureshort.wav')
# y is the signal data (amplitude), sr is the sample rate
# print(y.shape, sr)
#fig, ax = librosa.display.waveshow(y, sr=sr, ax=ax[0])

y, sr = librosa.load(librosa.ex('trumpet'), duration=10)

fig, ax = plt.subplots(nrows=1, sharex=True)
librosa.display.waveshow(y, sr=sr)


"""
plt.figure()
plt.plot(y)
plt.xlabel('time')
plt.ylabel('amplitude')
plt.plot()
"""
# Out:
# "\nplt.figure()\nplt.plot(y)\nplt.xlabel('time')\nplt.ylabel('amplitude')\nplt.plot()\n"
